# %% [markdown]
# **Name:** Manish Dhal
#
# **EID:** mdhal2

# %% [markdown]
# # CS4487 - Tutorial 5: Predicting Popularity of Online News
#
# In this tutorial you will train regression models to predict the number of "shares" of a news article on Mashable.
#
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import IPython.core.display         
# setup output image format (Chrome works best)
IPython.core.display.set_matplotlib_formats("svg")
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
from sklearn import *
import glob
import os
import csv
import string
random.seed(100)

# %% [markdown]
# ## 1. Loading Data and Pre-processing
# Next we need to load the data. **Unzip** `OnlineNewsPopularity.zip` in the same directory as this ipynb file.  Then run the following cell to load the data.

# %%
filename = 'OnlineNewsPopularity/OnlineNewsPopularity.csv'

# read the data
allfeatnames = []
textdata      = []
with open(filename, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        if len(allfeatnames)==0:
            allfeatnames = row
        else:
            textdata.append(row)

# put the data into a np array
dataX = empty((len(textdata), len(allfeatnames)-3))
dataY = empty(len(textdata))
for i,row in enumerate(textdata):
    # extract features (remove the first 2 features and the last feature)
    dataX[i,:] = array([float(x) for x in row[2:-1]])
    # extract target (last entry)
    dataY[i] = float(row[-1])
    
# extract feature names
featnames = [x.strip() for x in allfeatnames[2:-1]]

# extract a subset of data
dataX = dataX[::6]
dataY = dataY[::6]

print(dataX.shape)
print(dataY.shape)
# Out:
# (6608, 58)
# (6608,)

# %% [markdown]
# There are 58 features for each article.  Here are the feature names, and an example entry.  The actual description of the features can be found in the `OnlineNewsPopularity-features.txt` file.

# %%
print(featnames)

print("--- example article features---")
print(dataX[0])
print("--- example article target (# of shares)")
print(dataY[0])
# Out:
# ['n_tokens_title', 'n_tokens_content', 'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens', 'num_hrefs', 'num_self_hrefs', 'num_imgs', 'num_videos', 'average_token_length', 'num_keywords', 'data_channel_is_lifestyle', 'data_channel_is_entertainment', 'data_channel_is_bus', 'data_channel_is_socmed', 'data_channel_is_tech', 'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min', 'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg', 'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares', 'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday', 'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday', 'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00', 'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity', 'global_sentiment_polarity', 'global_rate_positive_words', 'global_rate_negative_words', 'rate_positive_words', 'rate_negative_words', 'avg_positive_polarity', 'min_positive_polarity', 'max_positive_polarity', 'avg_negative_polarity', 'min_negative_polarity', 'max_negative_polarity', 'title_subjectivity', 'title_sentiment_polarity', 'abs_title_subjectivity', 'abs_title_sentiment_polarity']
# --- example article features---
# [ 1.20000000e+01  2.19000000e+02  6.63594467e-01  9.99999992e-01
#   8.15384609e-01  4.00000000e+00  2.00000000e+00  1.00000000e+00
#   0.00000000e+00  4.68036530e+00  5.00000000e+00  0.00000000e+00
#   1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  4.96000000e+02  4.96000000e+02
#   4.96000000e+02  1.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  5.00331204e-01  3.78278930e-01  4.00046751e-02
#   4.12626477e-02  4.01225435e-02  5.21617145e-01  9.25619835e-02
#   4.56621005e-02  1.36986301e-02  7.69230769e-01  2.30769231e-01
#   3.78636364e-01  1.00000000e-01  7.00000000e-01 -3.50000000e-01
#  -6.00000000e-01 -2.00000000e-01  5.00000000e-01 -1.87500000e-01
#   0.00000000e+00  1.87500000e-01]
# --- example article target (# of shares)
# 593.0

# %% [markdown]
# Now separate the data into training and testing sets.

# %%
# randomly split data into 50% train and 50% test set
trainX, testX, trainYo, testYo = \
  model_selection.train_test_split(dataX, dataY, 
  train_size=0.50, test_size=0.50, random_state=4487)

print(trainX.shape)
print(testX.shape)
# Out:
# (3304, 58)
# (3304, 58)

# %% [markdown]
# Finally, we normalize the input features.

# %%
# normalize feature values
# this makes comparing weights more meaningful
scaler = preprocessing.StandardScaler()  
trainXn = scaler.fit_transform(trainX)  
testXn  = scaler.transform(testX)

# %% [markdown]
# Because the target value (number of shares) has a large dynamic range, we will transform the target values through the log function.

# %%
# map targets to log-space
trainY = log10(trainYo)
testY  = log10(testYo)

plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.hist(trainYo, 25);
plt.title('histogram of Y values')
plt.subplot(1,2,2)
plt.hist(trainY, 25);
plt.title("histogram of log(Y) values");

# %% [markdown]
# ## 2. Prediction with Linear Regression
#
# First we will look at predicting the number of shares using simple linear regression models.  Use the training data to fit a linear model using Ordinary Least Squares and Ridge Regression.  Use cross-validation on the training set to select the optimal $\alpha$ parameter for ridge regression.

# %%
### INSERT YOUR CODE HERE
## HINT: 
# 1. Ordinary Least Squares: linear_model.LinearRegression()
# 2. Ridge Regression: linear_model.Ridge(alphas= )
# 3. Rigge Regression with Cross-validation: linear_model.Ridge(alphas= )

ols = linear_model.LinearRegression()
ols.fit(trainXn , trainY)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
alphas = logspace(-5,15,30)

trainAEs = empty(len(alphas))
testAEs  = empty(len(alphas))
for i,a in enumerate(alphas):
    rr = linear_model.Ridge(alpha=a)
    rr.fit(trainXn, trainY)
    
    trainAEs[i] = metrics.mean_absolute_error(trainY, rr.predict(trainXn))
    testAEs[i]  = metrics.mean_absolute_error(testY, rr.predict(testXn))

plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.semilogx(alphas, trainAEs)
plt.xlabel('alpha')
plt.title('train AE')
plt.grid(True)
plt.subplot(1,2,2)
plt.semilogx(alphas, testAEs)
plt.xlabel('alpha')
plt.title('test AE')
plt.grid(True)
    
rr = linear_model.RidgeCV(alphas=alphas, cv=5)
rr.fit(trainXn, trainY)

print("best alpha: ", rr.alpha_)

trainAE = metrics.mean_absolute_error(trainY, rr.predict(trainXn))
testAE  = metrics.mean_absolute_error(testY,  rr.predict(testXn))

print("train error: ", trainAE)
print("test error : ", testAE)
# Out:
# best alpha:  385.6620421163472
# train error:  0.28859917591560874
# test error :  0.2854267347255127

# %% [markdown]
# Compare the two models using the _average absolute error_ (AE) between the predictions and the true values.  Below is  code that will calculate AE for the training and test sets.

# %%
# ols is the linear regression model
trainAE = metrics.mean_absolute_error(trainY, ols.predict(trainXn))
testAE  = metrics.mean_absolute_error(testY, ols.predict(testXn))
print("OLS: train error =", trainAE)
print("OLS: test error =", testAE)
# Out:
# OLS: train error = 0.2868996775835103
# OLS: test error = 187.02775149205695

# %%
# rr is the ridge regression model
trainAE = metrics.mean_absolute_error(trainY, rr.predict(trainXn))
testAE  = metrics.mean_absolute_error(testY, rr.predict(testXn))
print("RR: train error =", trainAE)
print("RR: test error =", testAE)
# Out:
# RR: train error = 0.28859917591560874
# RR: test error = 0.2854267347255127

# %% [markdown]
# Which model has better prediction ability on the test set? Why?
# - **Ridge regression performs better. OLS overfits the data and ridge regression prevents this using a penalty term.**

# %% [markdown]
# ## 3. Which features are important?
# Next we will investigate which features are the most important for the prediction.  Use LASSO with cross-validation to learn the model, and print the training and testing error.

# %%
### INSERT YOUR CODE HERE
## HINT
# 1. LASSO with Cross-validation: linear_model.LassoCV()

las = linear_model.LassoCV(alphas = logspace(-5,15,30))
las.fit(trainXn,trainY)
# Out:
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# LassoCV(alphas=array([1.00000000e-05, 4.89390092e-05, 2.39502662e-04, 1.17210230e-03,
#        5.73615251e-03, 2.80721620e-02, 1.37382380e-01, 6.72335754e-01,
#        3.29034456e+00, 1.61026203e+01, 7.88046282e+01, 3.85662042e+02,
#        1.88739182e+03, 9.23670857e+03, 4.52035366e+04, 2.21221629e+05,
#        1.08263673e+06, 5.29831691e+06, 2.59294380e+07, 1.26896100e+08,
#        6.21016942e+08, 3.03919538e+09, 1.48735211e+10, 7.27895384e+10,
#        3.56224789e+11, 1.74332882e+12, 8.53167852e+12, 4.17531894e+13,
#        2.04335972e+14, 1.00000000e+15]),
#         copy_X=True, cv='warn', eps=0.001, fit_intercept=True, max_iter=1000,
#         n_alphas=100, n_jobs=None, normalize=False, positive=False,
#         precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#         verbose=False)

# %%
las_predict_train = las.predict(trainXn)
print("las; training error =",metrics.mean_absolute_error(trainY , las_predict_train))

las_predict_test = las.predict(testXn)
print("las; test error =",metrics.mean_absolute_error(testY , las_predict_test))
# Out:
# las; training error = 0.28966720935858153
# las; test error = 0.28546981599559307

# %% [markdown]
# Examine the LASSO coefficients by sorting them in descending order.

# %%
# sort coefficients from smallest to largest, then reverse it
inds = argsort(abs(las.coef_))[::-1]
# print out
print("weight : feature description")
for i in inds:
    print("{: .3f} : {}".format(las.coef_[i], featnames[i]))
# Out:
# weight : feature description
#  0.080 : kw_avg_avg
# -0.043 : LDA_02
# -0.033 : data_channel_is_entertainment
# -0.026 : average_token_length
# -0.026 : kw_max_avg
#  0.024 : num_hrefs
#  0.022 : kw_min_min
#  0.022 : is_weekend
#  0.022 : global_subjectivity
#  0.019 : data_channel_is_socmed
#  0.018 : self_reference_avg_sharess
# -0.018 : data_channel_is_bus
#  0.017 : n_tokens_content
# -0.016 : kw_avg_min
#  0.013 : LDA_00
#  0.011 : title_sentiment_polarity
# -0.009 : data_channel_is_lifestyle
# -0.009 : max_positive_polarity
#  0.008 : weekday_is_sunday
# -0.008 : avg_negative_polarity
# -0.007 : LDA_01
#  0.006 : num_keywords
# -0.005 : kw_min_max
#  0.005 : n_tokens_title
# -0.004 : weekday_is_friday
#  0.004 : weekday_is_monday
#  0.003 : self_reference_max_shares
#  0.003 : LDA_03
# -0.003 : weekday_is_tuesday
#  0.002 : data_channel_is_tech
#  0.002 : num_imgs
# -0.001 : kw_avg_max
# -0.001 : min_positive_polarity
# -0.001 : rate_positive_words
# -0.000 : num_self_hrefs
#  0.000 : num_videos
# -0.000 : avg_positive_polarity
# -0.000 : min_negative_polarity
# -0.000 : max_negative_polarity
# -0.000 : n_non_stop_unique_tokens
# -0.000 : n_non_stop_words
# -0.000 : n_unique_tokens
#  0.000 : title_subjectivity
#  0.000 : rate_negative_words
# -0.000 : data_channel_is_world
#  0.000 : global_rate_negative_words
#  0.000 : weekday_is_thursday
# -0.000 : global_rate_positive_words
# -0.000 : kw_max_min
# -0.000 : global_sentiment_polarity
# -0.000 : LDA_04
# -0.000 : kw_max_max
#  0.000 : kw_min_avg
#  0.000 : weekday_is_saturday
#  0.000 : self_reference_min_shares
#  0.000 : abs_title_subjectivity
# -0.000 : weekday_is_wednesday
#  0.000 : abs_title_sentiment_polarity

# %% [markdown]
# _Which features are most important for predicting the number of shares?  For these features, which feature values (low or high values) will yield a higher number of shares?_
# - **kw_avg_avg,LDA_02,data_channel_is_entertainment, average_token_length,kw_max_avg are the most important features.**
#
# - **High values of kw_avg_avg will yield a higher number of sharees, but low values of the rest 4 would lead high values of shares.**

# %% [markdown]
# ## 3. Kernel Methods and Supprot Vector Regression
# Next, let us try some non-linear regression model such as[ kernel ridge regression](https://scikit-learn.org/stable/modules/kernel_ridge.html), [random forest regression](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)(Optional), [support vector regression](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html). To improve the prediction accuracy in Tutorial 4, and using cross-validation on the training set to select the parameters.

# %%
### INSERT YOUR CODE HERE
##Hint: 
## 1. Kernel Ridge Regression:  kernel_ridge.KernelRidge(kernel='rbf'/'poly')
## 2. Random Forest Regression: ensemble.RandomForestRegressor(random_state= , n_estimators= )
## 3. Support Vector Regression: svm.SVR(kernel='poly')
## 4. Avoid using large values of $C$ with SVR.



allexps = [
    {'name': 'krr-rbf',
     'clf': kernel_ridge.KernelRidge(kernel='rbf'),
     'params': {'alpha': logspace(-3,3,10), 'gamma': logspace(-6,3,10)}
    }, 
    {'name': 'krr-poly',
     'clf': kernel_ridge.KernelRidge(kernel='poly'),
     'params': {'alpha': logspace(-3,3,10), 'degree': [1,2,3,4,5]}
    }, 
    {'name': 'rf',
     'clf': ensemble.RandomForestRegressor(random_state=4487, n_estimators=100),
     'params': {'max_depth': array([1, 2, 3, 4, 5, 10, 15])}
    }, 
    {'name': 'svr-poly',
     'clf': svm.SVR(kernel='poly'),
     'params':  {'C': logspace(-3,0,5), 'degree': [1,2], 'epsilon': logspace(-2,2,5)}
    }, 
]

clfs = {}

trainAE = {}
testAE = {}

predYtrain = {}
predYtest = {}
for i,ex in enumerate(allexps):
    clfs[ex['name']] = model_selection.GridSearchCV(ex['clf'], ex['params'], cv=5, verbose=1, n_jobs=-1)
    clfs[ex['name']].fit(trainXn,trainY)
    predYtrain['name'] = clfs[ex['name']].predict(trainXn)
    predYtest['name'] = clfs[ex['name']].predict(testXn)
    trainAE[ex['name']] =metrics.mean_absolute_error(predYtrain['name'],trainY)
    testAE[ex['name']] = metrics.mean_absolute_error(predYtest['name'],testY)
    print('For '+ex['name']+':')
    print('\tTraining Mean Absolute Error: ' + str(trainAE[ex['name']]))
    print('\tTesting Mean Absolute Error: ' + str(testAE[ex['name']]))
    pass
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.5s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  2.0min finished
# For krr-rbf:
# 	Training Mean Absolute Error: 0.2717928728097602
# 	Testing Mean Absolute Error: 0.28055752767653014
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:   35.5s finished
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# For krr-poly:
# 	Training Mean Absolute Error: 0.26883106068172596
# 	Testing Mean Absolute Error: 0.27956156164035045
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:   17.8s finished
# For rf:
# 	Training Mean Absolute Error: 0.2006937262482335
# 	Testing Mean Absolute Error: 0.2840389476667905
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:   10.8s finished
# For svr-poly:
# 	Training Mean Absolute Error: 0.2812463784219451
# 	Testing Mean Absolute Error: 0.27492017267526386

# %%
min_score_item = None
for name,score in trainAE.items():
    if name == 'las-poly':
        continue
    if min_score_item is None:
        min_score_item = name
    elif testAE[min_score_item] < score:
        min_score_item = name
    
print ('Best non-linear regression model for train: ' + min_score_item)
print( 'Score :'+ str(trainAE[min_score_item]))
min_score_item = None
for name,score in testAE.items():
    if name == 'las-poly':
        continue
    if min_score_item is None:
        min_score_item = name
    elif testAE[min_score_item] < score:
        min_score_item = name
    
print ('Best non-linear regression model for test: ' + min_score_item)
print( 'Score :'+ str(testAE[min_score_item]))
# Out:
# Best non-linear regression model for train: svr-poly
# Score :0.2812463784219451
# Best non-linear regression model for test: rf
# Score :0.2840389476667905

# %%
# LASSO - poly features
polyfeats = preprocessing.PolynomialFeatures(degree=2)
trainXnf  = polyfeats.fit_transform(trainXn)
testXnf   = polyfeats.transform(testXn) 

myname = 'las-poly'
clfs[myname] = linear_model.LassoCV(max_iter=2000)
clfs[myname].fit(trainXnf, trainY)
trainAE[myname] = metrics.mean_absolute_error(trainY, clfs[myname].predict(trainXnf))
testAE[myname]  = metrics.mean_absolute_error(testY, clfs[myname].predict(testXnf))

print("train error:", trainAE[myname])
print("test error :", testAE[myname])
# Out:
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6762291032415533, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21052854236546636, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9882842501711764, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7404580364655544, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.4850672217586123, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2380823737517517, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.1196942426653607, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7581804519686557, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.4222994114772405, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1158327503620455, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8923298353786038, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8283367947639988, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.044926323910687, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.501706168769516, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.125173786670217, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.892687497269463, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.92899542874963, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.98739717792094, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.126793985619486, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.275095353991532, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.46425181507874, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.802902727185852, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.66773400474466, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.859705329122377, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.20054737837623, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.5998021745217, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.089604427037898, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.494570286568262, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.414505831571688, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.02998618352987, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4078957376296444, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.766214331812705, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7493475967772838, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9948943285575069, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.661060831626628, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.36693994562142507, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4313319059898504, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5565474592002033, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0398254342081259, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04358688921161047, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5134438431771571, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1094534076410696, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7761450684190834, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.643060709676632, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.131465808962702, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.258485577286876, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.596444266750353, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.290803309070384, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.462672097127353, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.4180814883503103, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.5699104466592075, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.970273987756457, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.703140026471061, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.19458890164438, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.221641523391241, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.5471969557633827, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.4815518584491656, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8499280422329605, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5227428588943894, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.05053533082571, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.3087999531091725, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.080733965620297, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.635051398969864, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12757234717417987, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.044970459713766786, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12907056352244695, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2031414930895039, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3425912775321365, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4267229372434258, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24045663428179864, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4563185546240902, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1638635197520841, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3940878210318886, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9411769454846137, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.32009619020573155, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3774350268041644, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1995995684281695, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.957090093676186, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# /Users/manishdhal/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.4323306064476924, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# train error: 0.2864570004788523
# test error : 0.2863086956691795

# %%
# sort coefficients from smallest to largest, then reverse it
inds = argsort(abs(clfs['las-poly'].coef_))[::-1]
print(len(polyfeats.powers_))
# print out
print("weight : feature description")
for i in inds:
    if abs(clfs['las-poly'].coef_[i])>1e-3:
        # get active features and powers
        pows = where(polyfeats.powers_[i])[0]
        fstr = ""
        for p in pows:
            fstr += featnames[p] + "(" + str(polyfeats.powers_[i][p]) + ") "
        print("{: .3f} : {}".format(clfs['las-poly'].coef_[i], fstr))
# Out:
# 1770
# weight : feature description
#  0.087 : kw_avg_avg(1)
#  0.017 : kw_min_avg(2)
# -0.014 : data_channel_is_entertainment(2)
# -0.012 : LDA_02(2)
#  0.009 : kw_min_min(2)
#  0.009 : kw_max_avg(1) LDA_00(1)
#  0.008 : data_channel_is_socmed(1) LDA_00(1)
#  0.008 : weekday_is_sunday(2)
#  0.007 : n_tokens_content(2)
# -0.007 : data_channel_is_world(1) rate_negative_words(1)
# -0.007 : data_channel_is_world(1) LDA_02(1)
#  0.006 : global_subjectivity(1)
# -0.006 : n_tokens_content(1) num_imgs(1)
# -0.006 : data_channel_is_lifestyle(1) max_positive_polarity(1)
#  0.006 : data_channel_is_tech(2)
#  0.005 : weekday_is_thursday(1) title_sentiment_polarity(1)
#  0.005 : num_keywords(1) kw_avg_max(1)
#  0.005 : num_videos(1) data_channel_is_bus(1)
# -0.005 : weekday_is_monday(1) title_sentiment_polarity(1)
# -0.005 : n_tokens_title(1) n_tokens_content(1)
# -0.005 : kw_max_max(1) title_sentiment_polarity(1)
#  0.005 : num_hrefs(2)
#  0.005 : data_channel_is_socmed(2)
#  0.004 : title_sentiment_polarity(1) abs_title_sentiment_polarity(1)
#  0.004 : weekday_is_saturday(2)
#  0.004 : n_unique_tokens(1) rate_negative_words(1)
#  0.003 : LDA_00(1) global_rate_positive_words(1)
# -0.003 : n_tokens_title(1) n_non_stop_words(1)
# -0.003 : num_imgs(1) data_channel_is_socmed(1)
#  0.003 : n_tokens_content(1) num_hrefs(1)
#  0.002 : LDA_00(2)
# -0.002 : kw_max_avg(2)
#  0.002 : kw_avg_avg(1) LDA_00(1)
# -0.002 : weekday_is_monday(1) global_rate_negative_words(1)
# -0.002 : kw_max_avg(1) kw_avg_avg(1)
# -0.002 : num_self_hrefs(2)
#  0.001 : kw_min_avg(1) weekday_is_monday(1)
# -0.001 : data_channel_is_lifestyle(2)
#  0.001 : LDA_03(1) rate_negative_words(1)
# -0.001 : LDA_03(1) global_rate_positive_words(1)
#  0.001 : weekday_is_friday(1) max_positive_polarity(1)
# -0.001 : data_channel_is_lifestyle(1) avg_positive_polarity(1)
#  0.001 : weekday_is_monday(2)

# %% [markdown]
# _Which regression method performs the best? Why do you think so?_
# - **polynomial (krr-poly, las-poly, and svr-poly) does slightly better.**
#
# - **interactions between features is important.**
