# %% [markdown]
# **Name:** Sai Navyanth VOBBILISETTY
#
# **EID:** svobbilis2

# %% [markdown]
# # CS4487 - Tutorial 5: Predicting Popularity of Online News
#
# In this tutorial you will train regression models to predict the number of "shares" of a news article on Mashable.
#
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import IPython.core.display         
# setup output image format (Chrome works best)
IPython.core.display.set_matplotlib_formats("svg")
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
from sklearn import *
import glob
import os
import csv
import string
random.seed(100)

# %% [markdown]
# ## 1. Loading Data and Pre-processing
# Next we need to load the data. **Unzip** `OnlineNewsPopularity.zip` in the same directory as this ipynb file.  Then run the following cell to load the data.

# %%
filename = 'OnlineNewsPopularity/OnlineNewsPopularity.csv'

# read the data
allfeatnames = []
textdata      = []
with open(filename, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        if len(allfeatnames)==0:
            allfeatnames = row
        else:
            textdata.append(row)

# put the data into a np array
dataX = empty((len(textdata), len(allfeatnames)-3))
dataY = empty(len(textdata))
for i,row in enumerate(textdata):
    # extract features (remove the first 2 features and the last feature)
    dataX[i,:] = array([float(x) for x in row[2:-1]])
    # extract target (last entry)
    dataY[i] = float(row[-1])
    
# extract feature names
featnames = [x.strip() for x in allfeatnames[2:-1]]

# extract a subset of data
dataX = dataX[::6]
dataY = dataY[::6]

print(dataX.shape)
print(dataY.shape)
# Out:
# (6608, 58)
# (6608,)

# %% [markdown]
# There are 58 features for each article.  Here are the feature names, and an example entry.  The actual description of the features can be found in the `OnlineNewsPopularity-features.txt` file.

# %%
print(featnames)

print("--- example article features---")
print(dataX[0])
print("--- example article target (# of shares)")
print(dataY[0])
# Out:
# ['n_tokens_title', 'n_tokens_content', 'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens', 'num_hrefs', 'num_self_hrefs', 'num_imgs', 'num_videos', 'average_token_length', 'num_keywords', 'data_channel_is_lifestyle', 'data_channel_is_entertainment', 'data_channel_is_bus', 'data_channel_is_socmed', 'data_channel_is_tech', 'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min', 'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg', 'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares', 'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday', 'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday', 'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00', 'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity', 'global_sentiment_polarity', 'global_rate_positive_words', 'global_rate_negative_words', 'rate_positive_words', 'rate_negative_words', 'avg_positive_polarity', 'min_positive_polarity', 'max_positive_polarity', 'avg_negative_polarity', 'min_negative_polarity', 'max_negative_polarity', 'title_subjectivity', 'title_sentiment_polarity', 'abs_title_subjectivity', 'abs_title_sentiment_polarity']
# --- example article features---
# [ 1.20000000e+01  2.19000000e+02  6.63594467e-01  9.99999992e-01
#   8.15384609e-01  4.00000000e+00  2.00000000e+00  1.00000000e+00
#   0.00000000e+00  4.68036530e+00  5.00000000e+00  0.00000000e+00
#   1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  4.96000000e+02  4.96000000e+02
#   4.96000000e+02  1.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  5.00331204e-01  3.78278930e-01  4.00046751e-02
#   4.12626477e-02  4.01225435e-02  5.21617145e-01  9.25619835e-02
#   4.56621005e-02  1.36986301e-02  7.69230769e-01  2.30769231e-01
#   3.78636364e-01  1.00000000e-01  7.00000000e-01 -3.50000000e-01
#  -6.00000000e-01 -2.00000000e-01  5.00000000e-01 -1.87500000e-01
#   0.00000000e+00  1.87500000e-01]
# --- example article target (# of shares)
# 593.0

# %% [markdown]
# Now separate the data into training and testing sets.

# %%
# randomly split data into 50% train and 50% test set
trainX, testX, trainYo, testYo = \
  model_selection.train_test_split(dataX, dataY, 
  train_size=0.50, test_size=0.50, random_state=4487)


print(trainX.shape)
print(testX.shape)
# Out:
# (3304, 58)
# (3304, 58)

# %% [markdown]
# Finally, we normalize the input features.

# %%
# normalize feature values
# this makes comparing weights more meaningful
scaler = preprocessing.StandardScaler()  
trainXn = scaler.fit_transform(trainX)  
testXn  = scaler.transform(testX)

# %% [markdown]
# Because the target value (number of shares) has a large dynamic range, we will transform the target values through the log function.

# %%
# map targets to log-space
trainY = log10(trainYo)
testY  = log10(testYo)

plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.hist(trainYo, 25);
plt.title('histogram of Y values')
plt.subplot(1,2,2)
plt.hist(trainY, 25);
plt.title("histogram of log(Y) values");

# %% [markdown]
# ## 2. Prediction with Linear Regression
#
# First we will look at predicting the number of shares using simple linear regression models.  Use the training data to fit a linear model using Ordinary Least Squares and Ridge Regression.  Use cross-validation on the training set to select the optimal $\alpha$ parameter for ridge regression.

# %%
### INSERT YOUR CODE HERE
## HINT: 
# 1. Ordinary Least Squares: linear_model.LinearRegression()
# 2. Ridge Regression: linear_model.Ridge(alphas= )
# 3. Rigge Regression with Cross-validation: linear_model.Ridge(alphas= )
ols = linear_model.LinearRegression()
ols.fit(trainXn,trainY)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
alphas = logspace(-5,15,30)

trainAEs = empty(len(alphas))
testAEs  = empty(len(alphas))
for i,a in enumerate(alphas):
    rr = linear_model.Ridge(alpha=a)
    rr.fit(trainXn, trainY)
    
    trainAEs[i] = metrics.mean_absolute_error(trainY, rr.predict(trainXn))
    testAEs[i]  = metrics.mean_absolute_error(testY, rr.predict(testXn))

plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.semilogx(alphas, trainAEs)
plt.xlabel('alpha')
plt.title('train AE')
plt.grid(True)
plt.subplot(1,2,2)
plt.semilogx(alphas, testAEs)
plt.xlabel('alpha')
plt.title('test AE')
plt.grid(True)
    
rr = linear_model.RidgeCV(alphas=alphas, cv=5)
rr.fit(trainX, trainY)

print("best alpha: ", rr.alpha_)

trainAE = metrics.mean_absolute_error(trainY, rr.predict(trainXn))
testAE  = metrics.mean_absolute_error(testY,  rr.predict(testXn))

print("train error: ", trainAE)
print("test error : ", testAE)
# Out:
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.21312e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.94705e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.82466e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.38919e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.95617e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.55125e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.42104e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.36114e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.63742e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.4255e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.24855e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.18483e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.15552e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.29072e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.18701e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.11026e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.7984e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.65495e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.31659e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.80908e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.99022e-17): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.83759e-17): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.76739e-17): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.0911e-17): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.84281e-17): result may not be accurate.
#   overwrite_a=True).T
# best alpha:  16.102620275609425
# train error:  0.4122275123891915
# test error :  0.40858013562207574

# %% [markdown]
# Compare the two models using the _average absolute error_ (AE) between the predictions and the true values.  Below is  code that will calculate AE for the training and test sets.

# %%
# ols is the linear regression model
trainAE = metrics.mean_absolute_error(trainY, ols.predict(trainXn))
testAE  = metrics.mean_absolute_error(testY, ols.predict(testXn))
print("OLS: train error =", trainAE)
print("OLS: test error =", testAE)
# Out:
# OLS: train error = 0.28689452135780136
# OLS: test error = 187.49243595582377

# %%
# rr is the ridge regression model
trainAE = metrics.mean_absolute_error(trainY, rr.predict(trainXn))
testAE  = metrics.mean_absolute_error(testY, rr.predict(testXn))
print("RR: train error =", trainAE)
print("RR: test error =", testAE)
# Out:
# RR: train error = 0.4122275123891915
# RR: test error = 0.40858013562207574

# %% [markdown]
# Which model has better prediction ability on the test set? Why?
# - **The ridge regression model has better prediction ability. Because, we can see that OLS is completely  overfitting and ridge regression uses a penalty term to reduce overfitting.**

# %% [markdown]
# ## 3. Which features are important?
# Next we will investigate which features are the most important for the prediction.  Use LASSO with cross-validation to learn the model, and print the training and testing error.

# %%
### INSERT YOUR CODE HERE
## HINT
# 1. LASSO with Cross-validation: linear_model.LassoCV()
las = linear_model.LassoCV(alphas = logspace(-5,15,30))
las.fit(trainXn,trainY)
# Out:
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# LassoCV(alphas=array([1.00000000e-05, 4.89390092e-05, 2.39502662e-04, 1.17210230e-03,
#        5.73615251e-03, 2.80721620e-02, 1.37382380e-01, 6.72335754e-01,
#        3.29034456e+00, 1.61026203e+01, 7.88046282e+01, 3.85662042e+02,
#        1.88739182e+03, 9.23670857e+03, 4.52035366e+04, 2.21221629e+05,
#        1.08263673e+06, 5.29831691e+06, 2.59294380e+07, 1.26896100e+08,
#        6.21016942e+08, 3.03919538e+09, 1.48735211e+10, 7.27895384e+10,
#        3.56224789e+11, 1.74332882e+12, 8.53167852e+12, 4.17531894e+13,
#        2.04335972e+14, 1.00000000e+15]),
#         copy_X=True, cv='warn', eps=0.001, fit_intercept=True, max_iter=1000,
#         n_alphas=100, n_jobs=None, normalize=False, positive=False,
#         precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#         verbose=False)

# %%
train_pred = las.predict(trainXn)
test_loss = metrics.mean_absolute_error(testY,las.predict(testX))
train_loss = metrics.mean_absolute_error(trainY,train_pred)

print("Training Error: {} and Test Error: {}".format(train_loss,test_loss))
# Out:
# Training Error: 0.2896672093585815 and Test Error: 311.243107319448

# %% [markdown]
# Examine the LASSO coefficients by sorting them in descending order.

# %%
# sort coefficients from smallest to largest, then reverse it
inds = argsort(abs(las.coef_))[::-1]
# print out
print("weight : feature description")
for i in inds:
    print("{: .3f} : {}".format(las.coef_[i], featnames[i]))
# Out:
# weight : feature description
#  0.080 : kw_avg_avg
# -0.043 : LDA_02
# -0.033 : data_channel_is_entertainment
# -0.026 : average_token_length
# -0.026 : kw_max_avg
#  0.024 : num_hrefs
#  0.022 : kw_min_min
#  0.022 : is_weekend
#  0.022 : global_subjectivity
#  0.019 : data_channel_is_socmed
#  0.018 : self_reference_avg_sharess
# -0.018 : data_channel_is_bus
#  0.017 : n_tokens_content
# -0.016 : kw_avg_min
#  0.013 : LDA_00
#  0.011 : title_sentiment_polarity
# -0.009 : data_channel_is_lifestyle
# -0.009 : max_positive_polarity
#  0.008 : weekday_is_sunday
# -0.008 : avg_negative_polarity
# -0.007 : LDA_01
#  0.006 : num_keywords
# -0.005 : kw_min_max
#  0.005 : n_tokens_title
# -0.004 : weekday_is_friday
#  0.004 : weekday_is_monday
#  0.003 : self_reference_max_shares
#  0.003 : LDA_03
# -0.003 : weekday_is_tuesday
#  0.002 : data_channel_is_tech
#  0.002 : num_imgs
# -0.001 : kw_avg_max
# -0.001 : min_positive_polarity
# -0.001 : rate_positive_words
# -0.000 : num_self_hrefs
#  0.000 : num_videos
# -0.000 : avg_positive_polarity
# -0.000 : min_negative_polarity
# -0.000 : max_negative_polarity
# -0.000 : n_non_stop_unique_tokens
# -0.000 : n_non_stop_words
# -0.000 : n_unique_tokens
#  0.000 : title_subjectivity
#  0.000 : rate_negative_words
# -0.000 : data_channel_is_world
#  0.000 : global_rate_negative_words
#  0.000 : weekday_is_thursday
# -0.000 : global_rate_positive_words
# -0.000 : kw_max_min
# -0.000 : global_sentiment_polarity
# -0.000 : LDA_04
# -0.000 : kw_max_max
#  0.000 : kw_min_avg
#  0.000 : weekday_is_saturday
#  0.000 : self_reference_min_shares
#  0.000 : abs_title_subjectivity
# -0.000 : weekday_is_wednesday
#  0.000 : abs_title_sentiment_polarity

# %% [markdown]
# _Which features are most important for predicting the number of shares?  For these features, which feature values (low or high values) will yield a higher number of shares?_
# - **kw_avg_avg,LDA_02,data_channel_is_entertainment, average_token_length,kw_max_avg are the most important features. High values of kw_avg_avg will yield a higher number of sharees, but low values of the rest 4 would lead high values of shares.**

# %% [markdown]
# ## 3. Kernel Methods and Supprot Vector Regression
# Next, let us try some non-linear regression model such as[ kernel ridge regression](https://scikit-learn.org/stable/modules/kernel_ridge.html), [random forest regression](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)(Optional), [support vector regression](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html). To improve the prediction accuracy in Tutorial 4, and using cross-validation on the training set to select the parameters.

# %%
### INSERT YOUR CODE HERE
##Hint: 
## 1. Kernel Ridge Regression:  kernel_ridge.KernelRidge(kernel='rbf'/'poly')
## 2. Random Forest Regression: ensemble.RandomForestRegressor(random_state= , n_estimators= )
## 3. Support Vector Regression: svm.SVR(kernel='poly')
## 4. Avoid using large values of $C$ with SVR.
kr=kernel_ridge.KernelRidge(kernel='rbf')
kr.fit(trainXn,trainY)
rf=ensemble.RandomForestRegressor( )
rf.fit(trainXn,trainY)
vr = svm.SVR(kernel='poly')
vr.fit(trainXn,trainY)
# Out:
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='poly', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
error={}
error["Kernel_Reg"]=metrics.mean_absolute_error(testY,kr.predict(testXn))
error["Rand_Reg"]=metrics.mean_absolute_error(testY, rf.predict(testXn))
error["Support Vector"]=metrics.mean_absolute_error(testY,vr.predict(testXn))

# %%
print("Kernel Ridge Regression Test Error: {}, Random Forest Regression Test Error: {},Support Vector Machine Regression Test Error: {}".format(error["Kernel_Reg"],error["Rand_Reg"],error["Support Vector"]))
# Out:
# Kernel Ridge Regression Test Error: 0.35770028920199565, Random Forest Regression Test Error: 0.30130773989110193,Support Vector Machine Regression Test Error: 0.29963570439758597

# %%
clfs = {}

# %%
# LASSO - poly features
polyfeats = preprocessing.PolynomialFeatures(degree=2)
trainXnf  = polyfeats.fit_transform(trainXn)
testXnf   = polyfeats.transform(testXn) 

myname = 'las-poly'
clfs[myname] = linear_model.LassoCV(max_iter=2000)
clfs[myname].fit(trainXnf, trainY)
trainAE[myname] = metrics.mean_absolute_error(trainY, clfs[myname].predict(trainXnf))
testAE[myname]  = metrics.mean_absolute_error(testY, clfs[myname].predict(testXnf))

print("train error:", trainAE[myname])
print("test error :", testAE[myname])
# Out:
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6762291032807752, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2105285423695591, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9882842501966707, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7404580364939761, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.485067221623382, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2380823730304087, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.119694242968592, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7581804513804116, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.4222994112016636, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1158327487613917, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8923298364765628, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8283367944271447, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.04492632500029, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.501706168641078, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.12517378883021, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.892687497559876, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.928995427050438, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.987397177736227, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.126793979663631, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.275095359391372, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.464251814629392, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.802902731966654, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.667734000784861, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.859705326348745, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.200547380680064, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.599802173079695, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.08960443400855, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.494570283473507, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.414505834712926, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.02998618639083, tolerance: 0.03771280016805898
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4078957376531207, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7662143318201515, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7493475966539336, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9948943286231611, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6610608318108575, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.366939945622903, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4313319060586025, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5565474588728989, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.039825434210882804, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04358688922607712, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.513443842752082, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.109453407876856, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.776145068170223, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.643060708527685, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.131465808201028, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.258485576355184, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.596444267179123, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2908033056922648, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.462672099497098, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.4180814885409063, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.569910445084872, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.970273987091588, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.703140028916408, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.194588902180442, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.221641522039022, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.547196959064138, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.481551858538012, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.849928045883729, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5227428601367592, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.050535330779411, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.308799952898568, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.080733971335746, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.635051380379366, tolerance: 0.038036995580736935
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12757234721317445, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04497045962438051, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12907056366174174, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20314149306651075, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3425912773364814, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.42672293731340005, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24045663432804076, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.45631855467362925, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1638635195940594, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3940878204195428, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9411769458256458, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3200961901051471, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3774350261672623, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1995995686772005, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.9570900939471585, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# C:\Users\bannu\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:471: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.4323306022935185, tolerance: 0.03789388576386035
#   tol, rng, random, positive)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-dd3670c0b0d1> in <module>
#       7 clfs[myname] = linear_model.LassoCV(max_iter=2000)
#       8 clfs[myname].fit(trainXnf, trainY)
# ----> 9 trainAE[myname] = metrics.mean_absolute_error(trainY, clfs[myname].predict(trainXnf))
#      10 testAE[myname]  = metrics.mean_absolute_error(testY, clfs[myname].predict(testXnf))
#      11
#
# TypeError: 'numpy.float64' object does not support item assignment

# %%
# sort coefficients from smallest to largest, then reverse it
inds = argsort(abs(clfs['las-poly'].coef_))[::-1]
print(len(polyfeats.powers_))
# print out
print("weight : feature description")
for i in inds:
    if abs(clfs['las-poly'].coef_[i])>1e-3:
        # get active features and powers
        pows = where(polyfeats.powers_[i])[0]
        fstr = ""
        for p in pows:
            fstr += featnames[p] + "(" + str(polyfeats.powers_[i][p]) + ") "
        print("{: .3f} : {}".format(clfs['las-poly'].coef_[i], fstr))
# Out:
# 1770
# weight : feature description
#  0.087 : kw_avg_avg(1)
#  0.017 : kw_min_avg(2)
# -0.014 : data_channel_is_entertainment(2)
# -0.012 : LDA_02(2)
#  0.009 : kw_min_min(2)
#  0.009 : kw_max_avg(1) LDA_00(1)
#  0.008 : data_channel_is_socmed(1) LDA_00(1)
#  0.008 : weekday_is_sunday(2)
#  0.007 : n_tokens_content(2)
# -0.007 : data_channel_is_world(1) rate_negative_words(1)
# -0.007 : data_channel_is_world(1) LDA_02(1)
#  0.006 : global_subjectivity(1)
# -0.006 : n_tokens_content(1) num_imgs(1)
# -0.006 : data_channel_is_lifestyle(1) max_positive_polarity(1)
#  0.006 : data_channel_is_tech(2)
#  0.005 : weekday_is_thursday(1) title_sentiment_polarity(1)
#  0.005 : num_keywords(1) kw_avg_max(1)
#  0.005 : num_videos(1) data_channel_is_bus(1)
# -0.005 : weekday_is_monday(1) title_sentiment_polarity(1)
# -0.005 : n_tokens_title(1) n_tokens_content(1)
# -0.005 : kw_max_max(1) title_sentiment_polarity(1)
#  0.005 : num_hrefs(2)
#  0.005 : data_channel_is_socmed(2)
#  0.004 : title_sentiment_polarity(1) abs_title_sentiment_polarity(1)
#  0.004 : weekday_is_saturday(2)
#  0.004 : n_unique_tokens(1) rate_negative_words(1)
#  0.003 : LDA_00(1) global_rate_positive_words(1)
# -0.003 : n_tokens_title(1) n_non_stop_words(1)
# -0.003 : num_imgs(1) data_channel_is_socmed(1)
#  0.003 : n_tokens_content(1) num_hrefs(1)
#  0.002 : LDA_00(2)
# -0.002 : kw_max_avg(2)
#  0.002 : kw_avg_avg(1) LDA_00(1)
# -0.002 : weekday_is_monday(1) global_rate_negative_words(1)
# -0.002 : kw_max_avg(1) kw_avg_avg(1)
# -0.002 : num_self_hrefs(2)
#  0.001 : kw_min_avg(1) weekday_is_monday(1)
# -0.001 : data_channel_is_lifestyle(2)
#  0.001 : LDA_03(1) rate_negative_words(1)
# -0.001 : LDA_03(1) global_rate_positive_words(1)
#  0.001 : weekday_is_friday(1) max_positive_polarity(1)
# -0.001 : data_channel_is_lifestyle(1) avg_positive_polarity(1)
#  0.001 : weekday_is_monday(2)

# %% [markdown]
# _Which regression method performs the best? Why do you think so?_
# - **Support Vector Regressor performs the best. This is because, SVM reduces overfitting and **
